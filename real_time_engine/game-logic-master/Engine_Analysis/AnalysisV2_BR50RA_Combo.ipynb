# %%
import pandas as pd
import seaborn as sns


data = pd.read_csv('GIS200_FinalModel_BR50_RA_combo.csv')
g=sns.pairplot(data,x_vars=['TurnNumber'], y_vars=['Accuracy'],height=7,aspect=0.7,diag_kind='line')

# %%
g=sns.relplot(x='TurnNumber', y='Accuracy',kind='line',data=data,height=10)

# %%
g=sns.relplot(x='TurnNumber', y='Specificity',kind='line',data=data,height=10)

# %%
g=sns.relplot(x='TurnNumber', y='Sensitivity',kind='line',data=data,height=10)

# %%
g=sns.relplot(x='TurnNumber', y='Precesion',kind='line',data=data,height=10)

# %%
g=sns.relplot(x='TurnNumber', y='FScore',kind='line',data=data,height=10)
